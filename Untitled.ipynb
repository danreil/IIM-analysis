# %% [markdown]
# Notebook version: using scipy and related packages for analysis and graphing of HistView data
# Copying the code from the code I was working on in Spyder. Trying notebook version out.
# Add more detailed comments comments later
